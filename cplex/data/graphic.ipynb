# %%
import matplotlib.pyplot as plt

# %% [markdown]
# PROLOG
# Basta copiar o código e mudar os valores

# %% [markdown]
# CPLEX

# %%
x_axis = [4,5,6,7]
y_axis = [0.06, 0.23, 0.13, 0.84]

plt.plot(x_axis, y_axis)
plt.title('cplex')
plt.xlabel('matrix NxN')
plt.ylabel('time(s)')
plt.show()

# %% [markdown]
# Prolog & Cplex

# %%
x_axis = [4,5,6,7]
y_cplex = [0.06, 0.23, 0.13, 0.84]
y_prolog = [1,2,3,4]

plt.plot(x_axis, y_cplex, label="cplex")
plt.plot(x_axis, y_prolog, label="prolog")
plt.title('Comparing two platform')
plt.xlabel('matrix NxN')
plt.ylabel('time(s)')
plt.show()
